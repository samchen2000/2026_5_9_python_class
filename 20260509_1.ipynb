# %% [markdown]
# <a href="https://colab.research.google.com/github/samchen2000/2026_5_9_python_class/blob/main/20260509_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello python")
name = "sam"
number = 100
print(type(name))
# Out:
# Hello python
# <class 'str'>

# %%
print("test")
# Out:
# test
