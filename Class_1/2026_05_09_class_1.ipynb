# %%
import math
name = "sam" # 字串(str)
avg = 50 # 整數(int)
weight = 105.8 #浮點數(float)
height = 182
birthday = int(2026 - avg)
lucky_ball = [1,10,100,1000] 
student = True #布林值(bool)
r = float(input("請輸入半徑"))
pi = 3.14159
arec = abs(round((pi * r**2),2)) #abs() : 回傳數值絕對值 , round() : 將數字四捨五入到指定小數位.
#arec = round(arec,1)
if lucky_ball[3] == 1000:
    lucky_ball.append(50)

print(f"我的名字是 : {name} ,  我的年齡 : {avg} ,我的出生年 : {birthday} , 我的體重 : {weight} , 我的身高 : {height} , 我是學生嗎 : {student}" )
if arec >= 200:
    if arec >= 400:
        arec = 400
        print(f"圓太大了超過{arec}改成 {arec}")
    else:
        print(f"{arec},圓有點大了,但在規範內.")
elif arec >= 100 and  arec < 200 :
     print(f"{arec}, 圓剛剛好!!")
else:
    print(f"{arec}, 圓太小了.")
for i in lucky_ball:
    if i == 1:
        print(f"目前數值是 : {i}, 數字有點小")
    elif i == 10:
        print(f"目前數字是 : {i},數字差不多")
    elif i == 100:
        print(f"目前數字是 : {i}, 數字有點大")
    else:
        print(f"{i}.....這數字哪來的??")
        #del lucky_ball[1]
print("程式結束oO0^___^0Oo!!!")
#lucky_ball.append(x) 在列表末尾添加一个元素 x
#lucky_ball.clear() 清空列表中的所有元素。
#lucky_ball.copy 返回列表的浅拷贝。
#lucky_ball.count 返回元素 x 在列表中出现的次数。
#lucky_ball.extend(iterable) 将一个可迭代对象（如列表、元组）中的所有元素添加到列表末尾)
#lucky_ball.index 返回第一个值为 x 的元素的索引。
#lucky_ball.insert(i, x) 在指定索引 i 处插入元素 x。
#lucky_ball.pop([i]) 移除并返回列表中索引为 i 的元素（默认是最后一个）。
#lucky_ball.remove(x) 移除列表中第一个值为 x 的元素。如果元素不存在，会抛出 ValueError。
#lucky_ball.reverse
#lucky_ball.sort

def any(is_ok):
    for i in is_ok:
        if i:
            return True
    return False

def test_1():
    print("設定程式進行")

def test_2(number):
    numberAdd = round(float(number + 20), 2)
    print(numberAdd) 
    
if __name__ == "__main__":
    print("程式開始_____")
    test_1()
    test_2(r)
# Out:
# 我的名字是 : sam ,  我的年齡 : 50 ,我的出生年 : 1976 , 我的體重 : 105.8 , 我的身高 : 182 , 我是學生嗎 : True
# 圓太大了超過400改成 400
# 目前數值是 : 1, 數字有點小
# 目前數字是 : 10,數字差不多
# 目前數字是 : 100, 數字有點大
# 1000.....這數字哪來的??
# 程式結束oO0^___^0Oo!!!
# 程式開始_____
# 設定程式進行
# 32.0

# %% [markdown]
# # 課程說明
# ## 課程說明
# ### 課程說明
# #### 課程說明
# ##### 課程說明
# ###### 課程說明
