# %%
import math
name = "sam"
avg = 50
weight = 105.8
height = 182
birthday = 1976
lucky_ball = [1,10,100] 
student = True
r = int(input("請輸入半徑"))
pi = 3.14159
arec = round((pi * r**2),2)
#arec = round(arec,1)
print(f"我的名字是 : {name} ,  我的年齡 : {avg} , 我的體重 : {weight} , 我的身高 : {height} , 園面積 : {arec}" )
if arec >= 200:
    if arec >= 400:
        arec = 400
    print(f"圓太大了改成 {arec}")
elif arec >= 100 and  arec < 200 :
     print("圓剛剛好!!")
else:
    print("圓太小了")
# Out:
# 我的名字是 : sam ,  我的年齡 : 50 , 我的體重 : 105.8 , 我的身高 : 182 , 園面積 : 452.39
# 圓太大了改成 400

# %% [markdown]
# # 課程說明
# ## 課程說明
# ### 課程說明
# #### 課程說明
# ##### 課程說明
# ###### 課程說明
