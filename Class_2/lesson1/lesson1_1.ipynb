# %%
while True:
    try:
        print("test_1")
        scress = int(input("請輸入300以內的數字"))
        if scress>300:
            print("數字太大")
        else:
            print(scress)
            break
    except:
        print("出錯了")
        break
# Out:
# test_1
# 數字太大
# test_1
# 數字太大
# test_1
# 20
