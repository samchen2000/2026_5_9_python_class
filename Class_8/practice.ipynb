# %%
class Car():
    def exclaim(self):
        print("我是一輛車")
    def check(self):
        print("我是一個四人座")
    def model(self):
        print("TOYUTA Alits")

# %%
my_car = Car()
my_car.exclaim()
# Out:
# 我是一輛車

# %%
class tuga(Car):
    pass

# %%
my_tuga = tuga()
my_tuga.exclaim()
my_tuga.check()
my_tuga.model()
# Out:
# 我是一輛車
# 我是一個四人座
# TOYUTA Alits
